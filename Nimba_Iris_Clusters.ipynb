# %% [markdown]
# # **Task-2: K-Means Clustering**
# In this task we are going to train the model on the 'Iris.csv' dataset and predict their optimum number of clusters!!

# %%
# Importing the all necessory libraries
import numpy as np
from  matplotlib import pyplot as plt
import pandas as pd
from sklearn import datasets

# %%
# Load the iris dataset
iris = datasets.load_iris()

# %%
type(iris)
# Out:
# sklearn.utils.Bunch

# %%
df_iris = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X = df_iris.values

# %%
X.shape
# Out:
# (150, 4)

# %%
from sklearn.cluster import KMeans

# %%
A =[]

for i in range(1,15):
  trainer = KMeans(n_clusters=i, init = 'k-means++' , n_init =10, random_state=42)

  trainer.fit(X)
  A.append(trainer.inertia_)

# %%
plt.plot(range(1,15), A)
plt.title("number of cluster Vs Within cluster sum of squares")
plt.xlabel("the elbow method")
plt.ylabel("Number of clusters")
plt.show()

# %%
print(max(A))
# Out:
# 681.3706

# %%
# Applying kmeans to the iris dataset / Creating the kmeans classifier
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# %%
print(y_kmeans.shape)
x =X
# Out:
# (150,)

# %%
# Visualising the clusters - On the first two columns
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')


# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()
